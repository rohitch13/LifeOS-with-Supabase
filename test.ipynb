# %% [markdown]
# # Imports

# %%
# %pip install -q numpy pandas matplotlib seaborn scikit-learn scipy requests beautifulsoup4 pillow  flask fastapi sqlalchemy jupyter ipykernel tqdm python-dotenv
# %pip install -q streamlit pandas numpy plotly pillow requests python-dotenv sqlalchemy sqlite-utils pydantic loguru schedule watchdog 
# %pip install -q supabase python-dotenv streamlit-supabase-auth
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly
print(plotly.__version__)
# Out:
# 6.5.2

# %% [markdown]
# # Supabase connection test

# %%
from supabase import create_client
from dotenv import load_dotenv
import os

load_dotenv()

url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")

supabase = create_client(url, key)

# Test connection
print("✅ Connected to Supabase successfully!")
print(f"Project URL: {url}")
# Out:
# ✅ Connected to Supabase successfully!
# Project URL: https://nwlcseasdloddqilhbuu.supabase.co

# %%
# http://localhost:8501 in google, supabse settings url conf

# %% [markdown]
# # Adding old expenses

# %%
# See SQL in Supabase
